# %%
import numpy as np
import pandas as pd

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
ten_micron = "Test_Data/8-21-19-10micron.csv"
fifteen_micron = "Test_Data/8-21-19-15micron.csv"
no_mesh = "Test_Data/8-20-19-nomesh(humidifier on at 50seconds).csv"
ten = pd.read_csv(ten_micron)
fifteen = pd.read_csv(fifteen_micron)
none = pd.read_csv(no_mesh)
dfs = [ten, fifteen, none]

# %%
# Processing 10 micron data
#Time index of when humidifier was activated was 14875
# start_index = pd.Index(df["Time"]).get_loc(14875)
# print(start_index)

ten["Time"] = (ten["Time"] - 14875) / 60000
ten.head(10)
# Out:
#        Time  Hum  Water  Pump  Fan1  Fan2  Si Humidity  Wet Humidity  \
# 0 -0.247917    0    312     0    50    40        94.31         83.92
# 1 -0.245450    0    208     0    50    40        94.23         86.51
# 2 -0.243000    0    205     0    50    40        94.25         86.50
# 3 -0.240567    0    264     0    50    40        94.22         86.50
# 4 -0.238100    0    264     0    50    40        94.21         86.51
# 5 -0.235650    0    333     0    50    40        94.23         86.51
# 6 -0.233183    0    200     0    50    40        94.24         86.51
# 7 -0.230750    0    138     0    50    40        94.22         86.51
# 8 -0.228283    0    141     0    50    40        94.24         86.51
# 9 -0.225833    0    270     0    50    40        94.25         86.51
#
#    Dry Humidity  Si Temperature  BME2 Temperature  BME1 Temperature  \
# 0         58.16           22.01             22.46              22.5
# 1         59.40           21.99             22.46              22.5
# 2         59.39           22.02             22.46              22.5
# 3         59.39           21.98             22.46              22.5
# 4         59.39           21.99             22.46              22.5
# 5         59.41           22.01             22.46              22.5
# 6         59.39           22.03             22.46              22.5
# 7         59.41           22.02             22.46              22.5
# 8         59.40           22.01             22.46              22.5
# 9         59.38           22.01             22.46              22.5
#
#    BME2 Pressure  BME1 Pressure
# 0        1014.25        1013.98
# 1        1014.25        1013.98
# 2        1014.25        1013.98
# 3        1014.26        1013.98
# 4        1014.26        1013.98
# 5        1014.26        1013.98
# 6        1014.26        1013.98
# 7        1014.26        1013.98
# 8        1014.26        1013.98
# 9        1014.26        1013.98

# %%
# Processing 15 micron data
# For fifteen micron humidifier started at 13984
fifteen["Time"] = (fifteen["Time"] - 13984) / 60000
fifteen.head(10)
# Out:
#        Time  Hum  Water  Pump  SmallFan  BigFan  Wet Humidity  Dry Humidity  \
# 0 -0.233067    0     49     0         0       0         75.95         56.93
# 1 -0.230917    0     69     0         0       0         78.17         58.11
# 2 -0.229017    0     75     0         0       0         78.19         58.11
# 3 -0.227117    0     77     0         0       0         78.21         58.14
# 4 -0.225200    0     78     0         0       0         78.21         58.07
# 5 -0.223300    0     78     0         0       0         78.22         58.10
# 6 -0.221400    0     80     0         0       0         78.23         58.10
# 7 -0.219483    0     80     0         0       0         78.24         58.10
# 8 -0.217583    0     80     0         0       0         78.25         58.11
# 9 -0.215683    0     80     0         0       0         78.25         58.03
#
#    Wet Temperature  Dry Temperature  Wet Pressure  Dry Pressure
# 0            23.02            22.74       1013.54       1013.70
# 1            23.02            22.74       1013.54       1013.70
# 2            23.02            22.74       1013.54       1013.71
# 3            23.02            22.74       1013.54       1013.71
# 4            23.02            22.74       1013.54       1013.71
# 5            23.02            22.74       1013.54       1013.71
# 6            23.02            22.74       1013.54       1013.71
# 7            23.02            22.74       1013.54       1013.71
# 8            23.02            22.74       1013.54       1013.71
# 9            23.02            22.74       1013.54       1013.71

# %%
# Processing no_mesh data
none["Time"] = (none["Time"] - 50000) / 60000
none.head(10)
# Out:
#        Time  Water  Pump  Fan1  Fan2  Si Humidity  Dry Humidity  Wet Humidity  \
# 0 -0.833333    185     0    50    40        68.74         49.53         59.94
# 1 -0.831017    137     0    50    40        68.68         50.36         61.29
# 2 -0.828683    290     0    50    40        68.68         50.37         61.30
# 3 -0.826350     94     0    50    40        68.70         50.37         61.30
# 4 -0.824017    186     0    50    40        68.71         50.38         61.31
# 5 -0.821700    230     0    50    40        68.71         50.38         61.32
# 6 -0.819367    178     0    50    40        68.72         50.38         61.32
# 7 -0.817033    245     0    50    40        68.73         50.39         61.33
# 8 -0.814700    176     0    50    40        68.76         50.39         61.33
# 9 -0.812367    257     0    50    40        68.75         50.39         61.34
#
#    Si Temperature  BME1 Temperature  BME2 Temperature
# 0           22.02             24.24             22.49
# 1           22.04             24.24             22.49
# 2           22.03             24.24             22.49
# 3           22.04             24.24             22.49
# 4           22.02             24.24             22.49
# 5           22.03             24.24             22.49
# 6           22.04             24.24             22.49
# 7           22.03             24.24             22.49
# 8           22.01             24.24             22.49
# 9           22.04             24.24             22.49

# %%
for f in dfs:
    f.set_index("Time", inplace=True)

# %%
plt.figure().suptitle('Humidity over Time in Wet Chamber')
plt.ylabel('Humidity %')
plt.xlabel('Time (min)')
ten["Wet Humidity"].plot(label="ten micron")
fifteen["Wet Humidity"].plot(label="fifteen micron")
none["Wet Humidity"].plot(label="no mesh")
plt.legend()
plt.show()

# %%
plt.figure().suptitle('Humidity over Time in Dry Chamber')
plt.ylabel('Humidity %')
plt.xlabel('Time (min)')
ten["Dry Humidity"].plot(label="ten micron")
fifteen["Dry Humidity"].plot(label="fifteen micron")
none["Dry Humidity"].plot(label="none")
plt.legend()
plt.show()
