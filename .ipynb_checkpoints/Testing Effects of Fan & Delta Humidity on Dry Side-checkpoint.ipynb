# %%
import numpy as np
import pandas as pd

# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams['figure.dpi']= 160

# %%
fan = pd.read_csv("Test_Data/09-03-19 const humidity vary fan.csv")#, index_col=0)
hum = pd.read_csv("Test_Data/09-03-19 const fan.csv")#, index_col=0)
dfs = [fan, hum]

# %%
# Filter Used to differentiate noisy data, https://github.com/stur86/tvregdiff
# Rick Chartrand, "Numerical differentiation of noisy, nonsmooth data," ISRN Applied Mathematics, Vol. 2011, Article ID 164564, 2011.

# import sys
from scipy import sparse
from scipy.sparse import linalg as splin

_has_matplotlib = True

# Utility function.

def chop(v):
    return v[1:]


def TVRegDiff(data, itern, alph, u0=None, scale='small', ep=1e-6, dx=None,
              plotflag=_has_matplotlib, diagflag=1):

    # code starts here
    # Make sure we have a column vector
    data = np.array(data)
    if (len(data.shape) != 1):
        print("Error - data is not a column vector")
        return
    # Get the data size.
    n = len(data)

    # Default checking. (u0 is done separately within each method.)
    if dx is None:
        dx = 1.0 / n

    # Different methods for small- and large-scale problems.
    if (scale.lower() == 'small'):

        # Construct differentiation matrix.
        c = np.ones(n + 1) / dx
        D = sparse.spdiags([-c, c], [0, 1], n, n + 1)

        DT = D.transpose()

        # Construct antidifferentiation operator and its adjoint.
        def A(x): return chop(np.cumsum(x) - 0.5 * (x + x[0])) * dx

        def AT(w): return (sum(w) * np.ones(n + 1) -
                           np.transpose(np.concatenate(([sum(w) / 2.0],
                                                        np.cumsum(w) -
                                                        w / 2.0)))) * dx

        # Default initialization is naive derivative

        if u0 is None:
            u0 = np.concatenate(([0], np.diff(data), [0]))

        u = u0
        # Since Au( 0 ) = 0, we need to adjust.
        ofst = data[0]
        # Precompute.
        ATb = AT(ofst - data)        # input: size n

        # Main loop.
        for ii in range(1, itern+1):
            # Diagonal matrix of weights, for linearizing E-L equation.
            Q = sparse.spdiags(1. / (np.sqrt((D * u)**2 + ep)), 0, n, n)
            # Linearized diffusion matrix, also approximation of Hessian.
            L = dx * DT * Q * D

            # Gradient of functional.
            g = AT(A(u)) + ATb + alph * L * u

            # Prepare to solve linear equation.
            tol = 1e-4
            maxit = 100
            # Simple preconditioner.
            P = alph * sparse.spdiags(L.diagonal() + 1, 0, n + 1, n + 1)

            def linop(v): return (alph * L * v + AT(A(v)))
            linop = splin.LinearOperator((n + 1, n + 1), linop)

            if diagflag:
                [s, info_i] = sparse.linalg.cg(
                    linop, g, x0=None, tol=tol, maxiter=maxit, callback=None,
                    M=P)
                print('iteration {0:4d}: relative change = {1:.3e}, '
                      'gradient norm = {2:.3e}\n'.format(ii,
                                                         np.linalg.norm(
                                                             s[0]) /
                                                         np.linalg.norm(u),
                                                         np.linalg.norm(g)))
                if (info_i > 0):
                    print("WARNING - convergence to tolerance not achieved!")
                elif (info_i < 0):
                    print("WARNING - illegal input or breakdown")
            else:
                [s, info_i] = sparse.linalg.cg(
                    linop, g, x0=None, tol=tol, maxiter=maxit, callback=None,
                    M=P)
            # Update solution.
            u = u - s
            # Display plot.
            if plotflag:
                plt.plot(u)
                plt.show()

    elif (scale.lower() == 'large'):

        # Construct antidifferentiation operator and its adjoint.
        def A(v): return np.cumsum(v)

        def AT(w): return (sum(w) * np.ones(len(w)) -
                           np.transpose(np.concatenate(([0.0],
                                                        np.cumsum(w[:-1])))))
        # Construct differentiation matrix.
        c = np.ones(n)
        D = sparse.spdiags([-c, c], [0, 1], n, n) / dx
        mask = np.ones((n, n))
        mask[-1, -1] = 0.0
        D = sparse.dia_matrix(D.multiply(mask))
        DT = D.transpose()
        # Since Au( 0 ) = 0, we need to adjust.
        data = data - data[0]
        # Default initialization is naive derivative.
        if u0 is None:
            u0 = np.concatenate(([0], np.diff(data)))
        u = u0
        # Precompute.
        ATd = AT(data)

        # Main loop.
        for ii in range(1, itern + 1):
            # Diagonal matrix of weights, for linearizing E-L equation.
            Q = sparse.spdiags(1. / np.sqrt((D*u)**2.0 + ep), 0, n, n)
            # Linearized diffusion matrix, also approximation of Hessian.
            L = DT*Q*D
            # Gradient of functional.
            g = AT(A(u)) - ATd
            g = g + alph * L * u
            # Build preconditioner.
            c = np.cumsum(range(n, 0, -1))
            B = alph * L + sparse.spdiags(c[::-1], 0, n, n)
            # droptol = 1.0e-2
            R = sparse.dia_matrix(np.linalg.cholesky(B.todense()))
            # Prepare to solve linear equation.
            tol = 1.0e-4
            maxit = 100

            def linop(v): return (alph * L * v + AT(A(v)))
            linop = splin.LinearOperator((n, n), linop)

            if diagflag:
                [s, info_i] = sparse.linalg.cg(
                    linop, -g, x0=None, tol=tol, maxiter=maxit, callback=None,
                    M=np.dot(R.transpose(), R))
                print('iteration {0:4d}: relative change = {1:.3e}, '
                      'gradient norm = {2:.3e}\n'.format(ii,
                                                         np.linalg.norm(s[0]) /
                                                         np.linalg.norm(u),
                                                         np.linalg.norm(g)))
                if (info_i > 0):
                    print("WARNING - convergence to tolerance not achieved!")
                elif (info_i < 0):
                    print("WARNING - illegal input or breakdown")

            else:
                [s, info_i] = sparse.linalg.cg(
                    linop, -g, x0=None, tol=tol, maxiter=maxit, callback=None,
                    M=np.dot(R.transpose(), R))
            # Update current solution
            u = u + s
            # Display plot.
            if plotflag:
                plt.plot(u/dx)
                plt.show()

        u = u/dx

    return u

# Small testing script


# if __name__ == "__main__":

#     dx = 0.05
#     x0 = np.arange(0, 2.0*np.pi, dx)

#     testf = np.sin(x0)

#     testf = testf + np.random.normal(0.0, 0.04, x0.shape)

#     deriv_sm = TVRegDiff(testf, 1, 5e-2, dx=dx,
#                          ep=1e-1, scale='small', plotflag=0)
#     deriv_lrg = TVRegDiff(testf, 100, 1e-1, dx=dx,
#                           ep=1e-2, scale='large', plotflag=0)

#     if (_has_matplotlib):
#         plt.plot(np.cos(x0), label='Analytical', c=(0,0,0))
#         plt.plot(np.gradient(testf, dx), label='numpy.gradient')
#         plt.plot(deriv_sm, label='TVRegDiff (small)')
#         plt.plot(deriv_lrg, label='TVRegDiff (large)')
#         plt.legend()
#         plt.show()

# %%
dx = 0.05
for df in dfs:
    df["Time(s)"] = df["Time"] / 1000 # Convert to Seconds
    df["Delta Humidity"] = df["Wet Humidity"] - df["Dry Humidity"]
    df["Time Interval"] = np.diff(np.concatenate(([0], df["Time(s)"])))
    deriv_sm = TVRegDiff(df["Wet Humidity"].data, 1, 5e-4, dx=dx, ep=1e-1, scale='small', plotflag=0)
    deriv_lrg = TVRegDiff(df["Wet Humidity"].data, 25, 1e-4,dx=dx, ep=1e-2, scale='large', plotflag=0)
    df["Wet Hum Gradient (sm)"] = pd.Series(deriv_sm)
    df["Wet Hum Gradient (lg)"] = pd.Series(deriv_sm)
    plt.plot(df["Wet Humidity"], label='Original')
    plt.plot(np.gradient(df["Wet Humidity"], dx), label='numpy.gradient')
    plt.plot(deriv_sm, label='TVRegDiff (small)')
    plt.plot(deriv_lrg, label='TVRegDiff (large)')
    plt.legend()
    plt.show()
    
#     df["Wet Hum Gradient"] = np.gradient(df["Wet Humidity"])/df["Time Interval"]
#     df["Dry Hum Gradient"] = np.gradient(df["Dry Humidity"])/df["Time Interval"]
    
#     df.replace([np.inf, -np.inf], np.nan, inplace=True)
# Out:
# C:\Users\Stefa\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: Series.data is deprecated and will be removed in a future version
# iteration    1: relative change = 1.186e-01, gradient norm = 7.983e+02
#
# WARNING - convergence to tolerance not achieved!
# C:\Users\Stefa\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: FutureWarning: Series.data is deprecated and will be removed in a future version
#   import sys
# iteration    1: relative change = 4.699e-04, gradient norm = 7.209e+03
#
# WARNING - convergence to tolerance not achieved!
# iteration    2: relative change = 8.045e-04, gradient norm = 6.656e+03
#
# WARNING - convergence to tolerance not achieved!
# iteration    3: relative change = 1.244e-03, gradient norm = 5.724e+03
#
# WARNING - convergence to tolerance not achieved!
# iteration    4: relative change = 2.270e-04, gradient norm = 4.581e+03
#
# WARNING - convergence to tolerance not achieved!
# iteration    5: relative change = 2.569e-04, gradient norm = 3.338e+03
#
# WARNING - convergence to tolerance not achieved!
# iteration    6: relative change = 1.090e-04, gradient norm = 2.549e+03
#
# WARNING - convergence to tolerance not achieved!
# iteration    7: relative change = 2.588e-05, gradient norm = 2.157e+03
#
# WARNING - convergence to tolerance not achieved!
# iteration    8: relative change = 5.674e-06, gradient norm = 1.740e+03
#
# WARNING - convergence to tolerance not achieved!
# iteration    9: relative change = 1.138e-05, gradient norm = 1.619e+03
#
# WARNING - convergence to tolerance not achieved!
# iteration   10: relative change = 2.290e-05, gradient norm = 1.293e+03
#
# WARNING - convergence to tolerance not achieved!
# iteration   11: relative change = 1.619e-05, gradient norm = 1.238e+03
#
# WARNING - convergence to tolerance not achieved!
# iteration   12: relative change = 2.014e-05, gradient norm = 1.009e+03
#
# WARNING - convergence to tolerance not achieved!
# iteration   13: relative change = 1.725e-05, gradient norm = 1.051e+03
#
# WARNING - convergence to tolerance not achieved!
# iteration   14: relative change = 1.921e-05, gradient norm = 7.896e+02
#
# WARNING - convergence to tolerance not achieved!
# iteration   15: relative change = 2.223e-05, gradient norm = 8.587e+02
#
# WARNING - convergence to tolerance not achieved!
# iteration   16: relative change = 9.165e-06, gradient norm = 7.059e+02
#
# WARNING - convergence to tolerance not achieved!
# iteration   17: relative change = 1.604e-05, gradient norm = 6.871e+02
#
# WARNING - convergence to tolerance not achieved!
# iteration   18: relative change = 2.805e-06, gradient norm = 6.422e+02
#
# WARNING - convergence to tolerance not achieved!
# iteration   19: relative change = 1.334e-05, gradient norm = 6.283e+02
#
# WARNING - convergence to tolerance not achieved!
# iteration   20: relative change = 5.485e-07, gradient norm = 5.716e+02
#
# WARNING - convergence to tolerance not achieved!
# iteration   21: relative change = 1.022e-05, gradient norm = 5.492e+02
#
# WARNING - convergence to tolerance not achieved!
# iteration   22: relative change = 2.812e-07, gradient norm = 4.772e+02
#
# WARNING - convergence to tolerance not achieved!
# iteration   23: relative change = 1.042e-05, gradient norm = 4.886e+02
#
# WARNING - convergence to tolerance not achieved!
# iteration   24: relative change = 8.700e-07, gradient norm = 4.567e+02
#
# WARNING - convergence to tolerance not achieved!
# iteration   25: relative change = 9.720e-06, gradient norm = 4.571e+02
#
# WARNING - convergence to tolerance not achieved!
# iteration    1: relative change = 1.538e+00, gradient norm = 8.277e+02
#
# WARNING - convergence to tolerance not achieved!
# iteration    1: relative change = 1.973e-03, gradient norm = 1.438e+04
#
# WARNING - convergence to tolerance not achieved!
# iteration    2: relative change = 1.368e-03, gradient norm = 1.321e+04
#
# WARNING - convergence to tolerance not achieved!
# iteration    3: relative change = 7.025e-04, gradient norm = 1.187e+04
#
# WARNING - convergence to tolerance not achieved!
# iteration    4: relative change = 9.031e-04, gradient norm = 9.778e+03
#
# WARNING - convergence to tolerance not achieved!
# iteration    5: relative change = 5.108e-04, gradient norm = 8.249e+03
#
# WARNING - convergence to tolerance not achieved!
# iteration    6: relative change = 2.622e-04, gradient norm = 7.073e+03
#
# WARNING - convergence to tolerance not achieved!
# iteration    7: relative change = 1.554e-04, gradient norm = 5.922e+03
#
# WARNING - convergence to tolerance not achieved!
# iteration    8: relative change = 9.467e-05, gradient norm = 5.537e+03
#
# WARNING - convergence to tolerance not achieved!
# iteration    9: relative change = 1.025e-04, gradient norm = 5.146e+03
#
# WARNING - convergence to tolerance not achieved!
# iteration   10: relative change = 7.851e-05, gradient norm = 4.991e+03
#
# WARNING - convergence to tolerance not achieved!
# iteration   11: relative change = 7.801e-05, gradient norm = 4.600e+03
#
# WARNING - convergence to tolerance not achieved!
# iteration   12: relative change = 7.535e-05, gradient norm = 4.364e+03
#
# WARNING - convergence to tolerance not achieved!
# iteration   13: relative change = 9.690e-05, gradient norm = 4.071e+03
#
# WARNING - convergence to tolerance not achieved!
# iteration   14: relative change = 7.035e-05, gradient norm = 3.931e+03
#
# WARNING - convergence to tolerance not achieved!
# iteration   15: relative change = 6.041e-05, gradient norm = 3.675e+03
#
# WARNING - convergence to tolerance not achieved!
# iteration   16: relative change = 8.513e-05, gradient norm = 3.640e+03
#
# WARNING - convergence to tolerance not achieved!
# iteration   17: relative change = 7.081e-05, gradient norm = 3.435e+03
#
# WARNING - convergence to tolerance not achieved!
# iteration   18: relative change = 6.791e-05, gradient norm = 3.398e+03
#
# WARNING - convergence to tolerance not achieved!
# iteration   19: relative change = 5.512e-05, gradient norm = 3.351e+03
#
# WARNING - convergence to tolerance not achieved!
# iteration   20: relative change = 5.944e-06, gradient norm = 3.064e+03
#
# WARNING - convergence to tolerance not achieved!
# iteration   21: relative change = 8.559e-04, gradient norm = 2.858e+03
#
# WARNING - convergence to tolerance not achieved!
# iteration   22: relative change = 1.840e-03, gradient norm = 2.427e+03
#
# WARNING - convergence to tolerance not achieved!
# iteration   23: relative change = 1.383e-03, gradient norm = 2.532e+03
#
# WARNING - convergence to tolerance not achieved!
# iteration   24: relative change = 1.433e-03, gradient norm = 1.890e+03
#
# WARNING - convergence to tolerance not achieved!
# iteration   25: relative change = 1.610e-03, gradient norm = 2.139e+03
#
# WARNING - convergence to tolerance not achieved!

# %%
fan.head(30)
# first_run.loc[first_run.index % 2 == 0,["Wet Humidity"]]
# Out:
#     Time  Hum  Water  Pump  SmallFan  BigFan  Wet Humidity  Dry Humidity  \
# 0      0    0     63     0         0      30         72.43         56.80
# 1    129    0     66     0         0      30         72.42         56.89
# 2    243    0     69     0         0      30         72.43         56.91
# 3    358    0     72     0         0      30         72.42         56.89
# 4    473    0     76     0         0      30         72.43         56.89
# 5    587    0     76     0         0      30         72.43         56.89
# 6    702    0    158     0         0      30         72.44         56.89
# 7    817    0    159     0         0      30         72.44         56.95
# 8    932    0    159     0         0      30         72.43         56.96
# 9   1046    0    160     0         0      30         72.42         56.89
# 10  1161    0    161     0         0      30         72.45         56.89
# 11  1276    0    162     0         0      30         72.46         56.89
# 12  1390    0    161     0         0      30         72.45         56.89
# 13  1505    0    163     0         0      30         72.45         56.93
# 14  1620    0    163     0         0      30         72.48         56.89
# 15  1734    0    163     0         0      30         72.46         56.89
# 16  1849    0     81     0         0      30         72.47         56.89
# 17  1964    0     82     0         0      30         72.47         56.89
# 18  2077    0     82     0         0      30         72.47         56.89
# 19  2192    0     82     0         0      30         72.48         57.03
# 20  2307    0     82     0         0      30         72.51         56.89
# 21  2421    0     82     0         0      30         72.49         56.89
# 22  2536    0     82     0         0      30         72.49         56.89
# 23  2651    0     81     0         0      30         72.50         56.89
# 24  2766    0     81     0         0      30         72.50         56.90
# 25  2880    0     82     0         0      30         72.51         56.85
# 26  2995    0     83     0         0      30         72.49         56.89
# 27  3110    0    162     0         0      30         72.52         56.90
# 28  3224    0    163     0         0      30         72.52         56.89
# 29  3339    0    163     0         0      30         72.53         56.90
#
#     Wet Temperature  Dry Temperature  Wet Pressure  Dry Pressure  Time(s)  \
# 0             22.74            23.07       1015.63       1016.20    0.000
# 1             22.74            23.07       1015.63       1016.20    0.129
# 2             22.74            23.07       1015.63       1016.20    0.243
# 3             22.74            23.07       1015.63       1016.20    0.358
# 4             22.74            23.07       1015.63       1016.20    0.473
# 5             22.74            23.07       1015.63       1016.20    0.587
# 6             22.74            23.07       1015.63       1016.20    0.702
# 7             22.74            23.07       1015.63       1016.20    0.817
# 8             22.74            23.07       1015.63       1016.21    0.932
# 9             22.74            23.07       1015.62       1016.21    1.046
# 10            22.74            23.07       1015.63       1016.21    1.161
# 11            22.74            23.07       1015.63       1016.21    1.276
# 12            22.74            23.07       1015.63       1016.21    1.390
# 13            22.74            23.07       1015.63       1016.21    1.505
# 14            22.74            23.07       1015.63       1016.21    1.620
# 15            22.74            23.07       1015.63       1016.21    1.734
# 16            22.74            23.07       1015.63       1016.21    1.849
# 17            22.74            23.07       1015.63       1016.21    1.964
# 18            22.74            23.07       1015.63       1016.21    2.077
# 19            22.74            23.07       1015.64       1016.21    2.192
# 20            22.74            23.07       1015.63       1016.21    2.307
# 21            22.74            23.07       1015.64       1016.21    2.421
# 22            22.75            23.07       1015.64       1016.21    2.536
# 23            22.75            23.07       1015.64       1016.21    2.651
# 24            22.75            23.07       1015.64       1016.21    2.766
# 25            22.75            23.07       1015.64       1016.21    2.880
# 26            22.75            23.07       1015.64       1016.21    2.995
# 27            22.75            23.07       1015.64       1016.21    3.110
# 28            22.75            23.07       1015.64       1016.21    3.224
# 29            22.75            23.07       1015.64       1016.21    3.339
#
#     Delta Humidity  Time Interval  Wet Hum Gradient  Dry Hum Gradient
# 0            15.63          0.000               NaN               NaN
# 1            15.53          0.129          0.000000          0.426357
# 2            15.52          0.114          0.000000          0.000000
# 3            15.53          0.115          0.000000         -0.086957
# 4            15.54          0.115          0.043478          0.000000
# 5            15.54          0.114          0.043860          0.000000
# 6            15.55          0.115          0.043478          0.260870
# 7            15.49          0.115         -0.043478          0.304348
# 8            15.47          0.115         -0.086957         -0.260870
# 9            15.53          0.114          0.087719         -0.307018
# 10           15.56          0.115          0.173913          0.000000
# 11           15.57          0.115          0.000000          0.000000
# 12           15.56          0.114         -0.043860          0.175439
# 13           15.52          0.115          0.130435          0.000000
# 14           15.59          0.115          0.043478         -0.173913
# 15           15.57          0.114         -0.043860          0.000000
# 16           15.58          0.115          0.043478          0.000000
# 17           15.58          0.115          0.000000          0.000000
# 18           15.58          0.113          0.044248          0.619469
# 19           15.45          0.115          0.173913          0.000000
# 20           15.62          0.115          0.043478         -0.608696
# 21           15.60          0.114         -0.087719          0.000000
# 22           15.60          0.115          0.043478          0.000000
# 23           15.61          0.115          0.043478          0.043478
# 24           15.60          0.115          0.043478         -0.173913
# 25           15.66          0.114         -0.043860         -0.043860
# 26           15.60          0.115          0.043478          0.217391
# 27           15.62          0.115          0.130435          0.000000
# 28           15.63          0.114          0.043860          0.000000
# 29           15.63          0.115          0.043478          0.304348

# %%
hum.head()
# Out:
#    Time  Hum  Water  Pump  SmallFan  BigFan  Wet Humidity  Dry Humidity  \
# 0     0    0     54     0         0      30         80.79         56.99
# 1   130    0     68     0         0      30         80.79         57.07
# 2   245    0     71     0         0      30         80.80         57.07
# 3   360    0    156     0         0      30         80.82         57.07
# 4   474    0    158     0         0      30         80.80         57.13
#
#    Wet Temperature  Dry Temperature  Wet Pressure  Dry Pressure  Time(s)  \
# 0            22.25            22.81       1015.76       1016.32    0.000
# 1            22.25            22.81       1015.76       1016.32    0.130
# 2            22.25            22.81       1015.76       1016.32    0.245
# 3            22.25            22.81       1015.76       1016.32    0.360
# 4            22.25            22.81       1015.76       1016.32    0.474
#
#    Delta Humidity  Time Interval  Wet Hum Gradient  Dry Hum Gradient
# 0           23.80          0.000               NaN               NaN
# 1           23.72          0.130          0.038462          0.307692
# 2           23.73          0.115          0.130435          0.000000
# 3           23.75          0.115          0.000000          0.260870
# 4           23.67          0.114         -0.087719          0.043860

# %%
plt.figure().suptitle('Rate of Change in Dry-side Humidity over Big Fan Speed')
plt.ylabel('Delta Humidity %')
plt.xlabel('Time (min)')
# Out:
# Text(0.5, 0, 'Time (min)')

# %%
# temp = np.array(first_run['Dry Hum Gradient'].values.tolist())
# first_run['Dry Hum Gradient'] = np.where(np.absolute(temp) > 0.5, 0, temp).tolist()
# temp = np.array(second_run['Dry Hum Gradient'].values.tolist())
# second_run['Dry Hum Gradient'] = np.where(np.absolute(temp) > 0.5, 0, temp).tolist()

# %%
fan.set_index("Time(s)")["Dry Hum Gradient"].plot(label="Varying Fan Speed")
hum.set_index("Time(s)")["Dry Hum Gradient"].plot(label="Varying Wet Humidity")
plt.legend()
plt.show()

# %%
plt.figure().suptitle('Rate of Change of Wet-side Humidity over Humidifier Power Output')
plt.ylabel('Delta Humidity %')
plt.xlabel('Hum Speed %')
first_run.set_index("Hum")["Wet Hum Gradient"].plot(label="First Run Gradient")
second_run.set_index("Hum")["Wet Hum Gradient"].plot(label="Second Run Gradient")
plt.legend()
plt.show()

# %%
plt.figure().suptitle('Humidity over Time in Dry Chamber')
plt.ylabel('Humidity %')
plt.xlabel('Time (min)')
first_run.set_index("Time")["Dry Hum Gradient"].plot(label="humidifier at 100%")
second_run.set_index("Time")["Dry Hum Gradient"].plot(label="humidifier at 50%")
plt.legend()
plt.show()

# %%
plt.figure().suptitle('Humidity over Time in Dry Chamber')
plt.ylabel('Humidity %')
plt.xlabel('Time (min)')
fifteen["Dry Humidity"].plot(label="humidifier at 100%")
halfhum_fifteen["Dry Humidity"].plot(label="humidifier at 50%")
plt.legend()
plt.show()
